# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
details=pd.read_csv("/home/hp/Downloads/Toyota.csv")

# %%
print(details)
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
price=[]

# %%
details.plot(kind='scatter',x='Price',y='Age')
plt.xlabel('Age in Years')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.hist(details['KM'],)
plt.title('Histogram of KM')
plt.xlabel('Kilometer')
plt.show()

# %%
plt.hist(details['CC'],)
plt.title('Histogram of CC')
plt.xlabel('CC')
plt.show()

# %%
fuel_count=pd.value_counts(details['FuelType'].values ,sort=True)
plt.xlabel('Frequency')
plt.ylabel('Fuel Type')
plt.title('Bar Plot of Fuel Type')
fuel_count.plot.bar()
